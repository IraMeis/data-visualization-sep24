# %%
import pandas as pd

# %%
df = pd.read_csv('data/Laptop-Price.csv')

# %%
df.head()
# Out:
#   Company          Product   TypeName  Inches             ScreenResolution  \
# 0      HP           250 G6   Notebook    15.6            Full HD 1920x1080
# 1    Acer         Aspire 3   Notebook    15.6                     1366x768
# 2    Asus  ZenBook UX430UN  Ultrabook    14.0            Full HD 1920x1080
# 3    Acer          Swift 3  Ultrabook    14.0  IPS Panel Full HD 1920x1080
# 4      HP           250 G6   Notebook    15.6                     1366x768
#
#     Ram       OpSys Cpu Brand       Cpu Model Cpu Rate  SSD  HDD  \
# 0   8GB       No OS     Intel   Core i5 7200U   2.5GHz  256    0
# 1   4GB  Windows 10       AMD  A9-Series 9420     3GHz    0  500
# 2  16GB  Windows 10     Intel   Core i7 8550U   1.8GHz  512    0
# 3   8GB  Windows 10     Intel   Core i5 8250U   1.6GHz  256    0
# 4   4GB       No OS     Intel   Core i5 7200U   2.5GHz    0  500
#
#    Flash Storage  Hybrid Gpu Brand         Gpu Model  Unnamed: 16  Price_euros
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Ram',
#        'OpSys', 'Cpu Brand', 'Cpu Model', 'Cpu Rate', 'SSD', 'HDD',
#        'Flash Storage', 'Hybrid', 'Gpu Brand', 'Gpu Model', 'Unnamed: 16',
#        'Price_euros'],
#       dtype='object')

# %%
df_laptop = df[['Company', 'Product', 'TypeName', 
                'Inches', 'ScreenResolution', 'Ram', 
                'OpSys', 'Cpu Model', 'SSD', 'HDD', 
                'Flash Storage', 'Hybrid', 
                'Gpu Model', 'Price_euros']]
df_cpu = df[['Cpu Brand', 'Cpu Model', 'Cpu Rate']]
df_gpu = df[['Gpu Brand', 'Gpu Model']]

# %%
df_laptop
# Out:
#      Company                                    Product            TypeName  \
# 0         HP                                     250 G6            Notebook
# 1       Acer                                   Aspire 3            Notebook
# 2       Asus                            ZenBook UX430UN           Ultrabook
# 3       Acer                                    Swift 3           Ultrabook
# 4         HP                                     250 G6            Notebook
# ...      ...                                        ...                 ...
# 1141    Dell                              Inspiron 3567            Notebook
# 1142    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1143  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1144  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1145      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
#
# ...

# %%
df_laptop.set_index('Product', inplace=True)
df_laptop
# Out:
#                                           Company            TypeName  Inches  \
# Product
# 250 G6                                         HP            Notebook    15.6
# Aspire 3                                     Acer            Notebook    15.6
# ZenBook UX430UN                              Asus           Ultrabook    14.0
# Swift 3                                      Acer           Ultrabook    14.0
# 250 G6                                         HP            Notebook    15.6
# ...                                           ...                 ...     ...
# Inspiron 3567                                Dell            Notebook    15.6
# X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce    Asus            Notebook    15.6
# Yoga 500-14ISK                             Lenovo  2 in 1 Convertible    14.0
# Yoga 900-13ISK                             Lenovo  2 in 1 Convertible    13.3
# 15-AC110nv (i7-6500U/6GB/1TB/Radeon            HP            Notebook    15.6
#
# ...

# %%
df_laptop = df_laptop.stack().rename_axis(['Product', 'Params']).reset_index(name='Value')
df_laptop
# Out:
#                                    Product            Params  \
# 0                                   250 G6           Company
# 1                                   250 G6          TypeName
# 2                                   250 G6            Inches
# 3                                   250 G6  ScreenResolution
# 4                                   250 G6               Ram
# ...                                    ...               ...
# 14893  15-AC110nv (i7-6500U/6GB/1TB/Radeon               HDD
# 14894  15-AC110nv (i7-6500U/6GB/1TB/Radeon     Flash Storage
# 14895  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Hybrid
# 14896  15-AC110nv (i7-6500U/6GB/1TB/Radeon         Gpu Model
# 14897  15-AC110nv (i7-6500U/6GB/1TB/Radeon       Price_euros
#
#                    Value
# 0                     HP
# 1               Notebook
# 2                   15.6
# 3      Full HD 1920x1080
# 4                    8GB
# ...                  ...
# 14893                  1
# ...

# %%
df_cpu
# Out:
#      Cpu Brand       Cpu Model Cpu Rate
# 0        Intel   Core i5 7200U   2.5GHz
# 1          AMD  A9-Series 9420     3GHz
# 2        Intel   Core i7 8550U   1.8GHz
# 3        Intel   Core i5 8250U   1.6GHz
# 4        Intel   Core i5 7200U   2.5GHz
# ...        ...             ...      ...
# 1141     Intel   Core i7 7500U   2.7GHz
# 1142     Intel   Core i7 6500U   2.5GHz
# 1143     Intel   Core i7 6500U   2.5GHz
# 1144     Intel   Core i7 6500U   2.5GHz
# 1145     Intel   Core i7 6500U   2.5GHz
#
# [1146 rows x 3 columns]

# %%
df_cpu.drop_duplicates(inplace=True)
df_cpu
# Out:
# /tmp/ipykernel_8790/957761418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cpu.drop_duplicates(inplace=True)
#      Cpu Brand       Cpu Model Cpu Rate
# 0        Intel   Core i5 7200U   2.5GHz
# 1          AMD  A9-Series 9420     3GHz
# 2        Intel   Core i7 8550U   1.8GHz
# 3        Intel   Core i5 8250U   1.6GHz
# 5        Intel   Core i3 6006U     2GHz
# ...        ...             ...      ...
# 983      Intel     Core M 6Y54   1.1GHz
# 1015     Intel   Core i7 6500U  2.50GHz
# 1071       AMD   E-Series 9000   2.2GHz
# 1119     Intel     Core M 6Y30   0.9GHz
# 1122       AMD  A9-Series 9410   2.9GHz
#
# [78 rows x 3 columns]

# %%
df_gpu = df_gpu.drop_duplicates().set_index('Gpu Model').reset_index()

# %%
df_gpu
# Out:
#            Gpu Model Gpu Brand
# 0    HD Graphics 620     Intel
# 1          Radeon R5       AMD
# 2      GeForce MX150    Nvidia
# 3   UHD Graphics 620     Intel
# 4    HD Graphics 520     Intel
# ..               ...       ...
# 91    Radeon R5 M315       AMD
# 92      Quadro M500M    Nvidia
# 93    Radeon R7 M360       AMD
# 94     Quadro M3000M    Nvidia
# 95      GeForce 960M    Nvidia
#
# [96 rows x 2 columns]
